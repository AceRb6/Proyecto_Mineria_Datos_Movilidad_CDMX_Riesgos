# %%
from sqlalchemy import create_engine
import urllib.parse
import sys
import pandas as pd

# --- CONFIGURACIÓN SEGURA DE CONEXIÓN ---
USER = "postgres"
PASSWORD = "as52"  
HOST = "localhost"
PORT = "5432"
DB_NAME = "Historico_Hechos_Movilidad" 

password_safe = urllib.parse.quote_plus(PASSWORD)
user_safe = urllib.parse.quote_plus(USER)
db_name_safe = urllib.parse.quote_plus(DB_NAME)
db_connection_str = f'postgresql+psycopg2://{user_safe}:{password_safe}@{HOST}:{PORT}/{db_name_safe}'

try:
    engine = create_engine(
        db_connection_str, 
        connect_args={'client_encoding': 'utf8'}
    )
    with engine.connect() as connection:
        print("Conexión a Base de Datos EXITOSA.")
except Exception as e:
    print(f"ERROR DE CONEXIÓN: {e}")
    sys.exit(1)

def carga_definitiva(ruta_csv, nombre_tabla, mapeo_cols):
    print(f"\n[{nombre_tabla}] Iniciando carga blindada...")
    
    # 1. Ajuste de chunksize: Si la fila es muy ancha, reduce esto a 10000
    chunksize = 50000 
    
    try:
        iterator = pd.read_csv(
            ruta_csv, 
            chunksize=chunksize, 
            encoding='cp1252', 
            encoding_errors='replace',
            engine='python',
            on_bad_lines='skip'
        )
        
        total_rows = 0
        for i, df in enumerate(iterator):
            
            df.columns = [c.strip().lower() for c in df.columns]
            
            cols_corregidas = {}
            for col in df.columns:
                if 'fecha' in col and len(col) > 5: 
                    cols_corregidas[col] = 'fecha'
            
            if cols_corregidas:
                df = df.rename(columns=cols_corregidas)
            
            if 'estacion' in df.columns:
                df = df.drop(columns=['estacion'])
            
            df = df.rename(columns={'estacion_normalizada': 'nombre_estacion'})

            df = df.rename(columns=mapeo_cols)
            
            if 'longitud' in df.columns and 'latitud' in df.columns:
                mask = df['longitud'].notnull() & df['latitud'].notnull()
                df.loc[mask, 'geometria'] = df[mask].apply(
                    lambda x: f"SRID=4326;POINT({x['longitud']} {x['latitud']})", axis=1
                )
            
            if 'fk_tiempo' in df.columns:
                 df['fk_tiempo'] = pd.to_datetime(df['fk_tiempo'], errors='coerce')

            cols_validas = [c for c in df.columns if c in mapeo_cols.values() or c == 'geometria']
            df = df[cols_validas]

            df.to_sql(nombre_tabla, engine, if_exists='append', index=False, method='multi', chunksize=5000)
            total_rows += len(df)
            print(f"   -> Bloque {i+1} OK. Filas acumuladas: {total_rows}")

        print(f"CARGA COMPLETADA: {nombre_tabla} ({total_rows} filas)")

    except Exception as e:
        print(f"ERROR CRÍTICO EN BLOQUE {total_rows // chunksize}: {e}")
        import traceback
        traceback.print_exc()
        sys.exit(1)

mapa_metro_ajustado = {
    'fecha': 'fk_tiempo', 
    'nombre_estacion': 'nombre_estacion',
    'linea': 'linea', 
    'afluencia': 'afluencia', 
    'latitud': 'latitud', 
    'longitud': 'longitud',
    'score_atlas': 'score_atlas', 
    'flag_historico': 'flag_historico', 
    'nivel_riesgo_estatico': 'nivel_riesgo_estatico'
}

carga_definitiva(r"Data_Tratado\Afluencia_Metro_Enriquecido.csv", "fact_afluencia_metro", mapa_metro_ajustado)
# Out:
# ✅ Conexión a Base de Datos EXITOSA.
#
# [fact_afluencia_metro] Iniciando carga blindada...
#    -> Bloque 1 OK. Filas acumuladas: 50000
#    -> Bloque 2 OK. Filas acumuladas: 100000
#    -> Bloque 3 OK. Filas acumuladas: 150000
#    -> Bloque 4 OK. Filas acumuladas: 200000
#    -> Bloque 5 OK. Filas acumuladas: 250000
#    -> Bloque 6 OK. Filas acumuladas: 300000
#    -> Bloque 7 OK. Filas acumuladas: 350000
#    -> Bloque 8 OK. Filas acumuladas: 400000
#    -> Bloque 9 OK. Filas acumuladas: 450000
#    -> Bloque 10 OK. Filas acumuladas: 500000
#    -> Bloque 11 OK. Filas acumuladas: 550000
#    -> Bloque 12 OK. Filas acumuladas: 600000
#    -> Bloque 13 OK. Filas acumuladas: 650000
#    -> Bloque 14 OK. Filas acumuladas: 700000
#    -> Bloque 15 OK. Filas acumuladas: 750000
#    -> Bloque 16 OK. Filas acumuladas: 800000
#    -> Bloque 17 OK. Filas acumuladas: 850000
#    -> Bloque 18 OK. Filas acumuladas: 900000
#    -> Bloque 19 OK. Filas acumuladas: 950000
#    -> Bloque 20 OK. Filas acumuladas: 1000000
#    -> Bloque 21 OK. Filas acumuladas: 1050000
#    -> Bloque 22 OK. Filas acumuladas: 1100000
#    -> Bloque 23 OK. Filas acumuladas: 1150000
#    -> Bloque 24 OK. Filas acumuladas: 1200000
#    -> Bloque 25 OK. Filas acumuladas: 1250000
#    -> Bloque 26 OK. Filas acumuladas: 1300000
#    -> Bloque 27 OK. Filas acumuladas: 1350000
#    -> Bloque 28 OK. Filas acumuladas: 1400000
#    -> Bloque 29 OK. Filas acumuladas: 1450000
#    -> Bloque 30 OK. Filas acumuladas: 1500000
#    -> Bloque 31 OK. Filas acumuladas: 1550000
#    -> Bloque 32 OK. Filas acumuladas: 1600000
#    -> Bloque 33 OK. Filas acumuladas: 1650000
#    -> Bloque 34 OK. Filas acumuladas: 1700000
#    -> Bloque 35 OK. Filas acumuladas: 1750000
#    -> Bloque 36 OK. Filas acumuladas: 1800000
#    -> Bloque 37 OK. Filas acumuladas: 1850000
#    -> Bloque 38 OK. Filas acumuladas: 1900000
#    -> Bloque 39 OK. Filas acumuladas: 1950000
#    -> Bloque 40 OK. Filas acumuladas: 2000000
#    -> Bloque 41 OK. Filas acumuladas: 2050000
#    -> Bloque 42 OK. Filas acumuladas: 2100000
#    -> Bloque 43 OK. Filas acumuladas: 2150000
#    -> Bloque 44 OK. Filas acumuladas: 2200000
#    -> Bloque 45 OK. Filas acumuladas: 2250000
#    -> Bloque 46 OK. Filas acumuladas: 2300000
#    -> Bloque 47 OK. Filas acumuladas: 2350000
#    -> Bloque 48 OK. Filas acumuladas: 2400000
#    -> Bloque 49 OK. Filas acumuladas: 2450000
#    -> Bloque 50 OK. Filas acumuladas: 2500000
#    -> Bloque 51 OK. Filas acumuladas: 2550000
#    -> Bloque 52 OK. Filas acumuladas: 2600000
#    -> Bloque 53 OK. Filas acumuladas: 2650000
#    -> Bloque 54 OK. Filas acumuladas: 2700000
#    -> Bloque 55 OK. Filas acumuladas: 2750000
#    -> Bloque 56 OK. Filas acumuladas: 2800000
#    -> Bloque 57 OK. Filas acumuladas: 2850000
#    -> Bloque 58 OK. Filas acumuladas: 2900000
#    -> Bloque 59 OK. Filas acumuladas: 2950000
#    -> Bloque 60 OK. Filas acumuladas: 3000000
#    -> Bloque 61 OK. Filas acumuladas: 3050000
#    -> Bloque 62 OK. Filas acumuladas: 3100000
#    -> Bloque 63 OK. Filas acumuladas: 3150000
#    -> Bloque 64 OK. Filas acumuladas: 3200000
#    -> Bloque 65 OK. Filas acumuladas: 3250000
#    -> Bloque 66 OK. Filas acumuladas: 3300000
#    -> Bloque 67 OK. Filas acumuladas: 3350000
#    -> Bloque 68 OK. Filas acumuladas: 3400000
#    -> Bloque 69 OK. Filas acumuladas: 3450000
#    -> Bloque 70 OK. Filas acumuladas: 3500000
#    -> Bloque 71 OK. Filas acumuladas: 3550000
#    -> Bloque 72 OK. Filas acumuladas: 3600000
#    -> Bloque 73 OK. Filas acumuladas: 3650000
#    -> Bloque 74 OK. Filas acumuladas: 3700000
#    -> Bloque 75 OK. Filas acumuladas: 3750000
#    -> Bloque 76 OK. Filas acumuladas: 3800000
#    -> Bloque 77 OK. Filas acumuladas: 3850000
#    -> Bloque 78 OK. Filas acumuladas: 3900000
#    -> Bloque 79 OK. Filas acumuladas: 3950000
#    -> Bloque 80 OK. Filas acumuladas: 4000000
#    -> Bloque 81 OK. Filas acumuladas: 4050000
#    -> Bloque 82 OK. Filas acumuladas: 4100000
#    -> Bloque 83 OK. Filas acumuladas: 4150000
#    -> Bloque 84 OK. Filas acumuladas: 4200000
#    -> Bloque 85 OK. Filas acumuladas: 4250000
#    -> Bloque 86 OK. Filas acumuladas: 4300000
#    -> Bloque 87 OK. Filas acumuladas: 4350000
#    -> Bloque 88 OK. Filas acumuladas: 4400000
#    -> Bloque 89 OK. Filas acumuladas: 4450000
#    -> Bloque 90 OK. Filas acumuladas: 4500000
#    -> Bloque 91 OK. Filas acumuladas: 4550000
#    -> Bloque 92 OK. Filas acumuladas: 4600000
#    -> Bloque 93 OK. Filas acumuladas: 4650000
#    -> Bloque 94 OK. Filas acumuladas: 4700000
#    -> Bloque 95 OK. Filas acumuladas: 4750000
#    -> Bloque 96 OK. Filas acumuladas: 4800000
#    -> Bloque 97 OK. Filas acumuladas: 4850000
#    -> Bloque 98 OK. Filas acumuladas: 4900000
#    -> Bloque 99 OK. Filas acumuladas: 4950000
#    -> Bloque 100 OK. Filas acumuladas: 5000000
#    -> Bloque 101 OK. Filas acumuladas: 5050000
#    -> Bloque 102 OK. Filas acumuladas: 5100000
#    -> Bloque 103 OK. Filas acumuladas: 5139574
# ✅ CARGA COMPLETADA: fact_afluencia_metro (5139574 filas)

# %%
import pandas as pd
from sqlalchemy import create_engine
import sys

# CONEXIÓN
db_connection_str = 'postgresql+psycopg2://postgres:as52@localhost:5432/Historico_Hechos_Movilidad'
engine = create_engine(db_connection_str)

def carga_definitiva(ruta_csv, nombre_tabla, mapeo_cols):
    print(f"\n[{nombre_tabla}] Iniciando carga...")
    chunksize = 50000 
    
    try:
        iterator = pd.read_csv(ruta_csv, chunksize=chunksize, encoding='latin-1')
        
        total_rows = 0
        for i, df in enumerate(iterator):
            # 1. Renombrar columnas
            df = df.rename(columns=mapeo_cols)
            
            # 2. Geometría PostGIS
            if 'longitud' in df.columns and 'latitud' in df.columns:
                mask = df['longitud'].notnull() & df['latitud'].notnull()
                df.loc[mask, 'geometria'] = df[mask].apply(
                    lambda x: f"SRID=4326;POINT({x['longitud']} {x['latitud']})", axis=1
                )
            
            # 3. Fechas
            if 'fk_tiempo' in df.columns:
                 df['fk_tiempo'] = pd.to_datetime(df['fk_tiempo'], errors='coerce')

            # 4. Filtrar columnas útiles
            cols_validas = [c for c in df.columns if c in mapeo_cols.values() or c == 'geometria']
            df = df[cols_validas]

            # 5. Insertar
            df.to_sql(nombre_tabla, engine, if_exists='append', index=False, method='multi', chunksize=5000)
            total_rows += len(df)
            print(f"   -> Bloque {i+1} OK. Filas totales: {total_rows}")

        print(f"CARGA COMPLETADA: {nombre_tabla} ({total_rows} filas)")

    except Exception as e:
        print(f"ERROR CRÍTICO: {e}")
        sys.exit(1)

# --- CONFIGURACIÓN ESPECÍFICA PARA ESTE SCRIPT ---
mapa_inviales = {
    'fecha_creacion': 'fk_tiempo', 'hora_creacion': 'hora_creacion', 'latitud': 'latitud',
    'longitud': 'longitud', 'tipo_incidente': 'tipo_incidente', 'alcaldia': 'alcaldia',
    'SCORE_ATLAS': 'score_atlas', 'FLAG_HISTORICO': 'flag_historico', 'NIVEL_RIESGO_ESTATICO': 'nivel_riesgo_estatico'
}

# EJECUCIÓN
carga_definitiva(r"Data_Tratado\Inviales_Enriquecido.csv", "fact_inviales", mapa_inviales)
# Out:
# [fact_inviales] Iniciando carga...
#    -> Bloque 1 OK. Filas totales: 50000
#    -> Bloque 2 OK. Filas totales: 100000
#    -> Bloque 3 OK. Filas totales: 150000
#    -> Bloque 4 OK. Filas totales: 200000
#    -> Bloque 5 OK. Filas totales: 250000
#    -> Bloque 6 OK. Filas totales: 300000
#    -> Bloque 7 OK. Filas totales: 350000
#    -> Bloque 8 OK. Filas totales: 400000
#    -> Bloque 9 OK. Filas totales: 450000
#    -> Bloque 10 OK. Filas totales: 500000
#    -> Bloque 11 OK. Filas totales: 550000
#    -> Bloque 12 OK. Filas totales: 600000
#    -> Bloque 13 OK. Filas totales: 650000
#    -> Bloque 14 OK. Filas totales: 700000
#    -> Bloque 15 OK. Filas totales: 750000
#    -> Bloque 16 OK. Filas totales: 800000
#    -> Bloque 17 OK. Filas totales: 850000
#    -> Bloque 18 OK. Filas totales: 900000
#    -> Bloque 19 OK. Filas totales: 950000
#    -> Bloque 20 OK. Filas totales: 1000000
#    -> Bloque 21 OK. Filas totales: 1050000
#    -> Bloque 22 OK. Filas totales: 1100000
#    -> Bloque 23 OK. Filas totales: 1150000
#    -> Bloque 24 OK. Filas totales: 1200000
#    -> Bloque 25 OK. Filas totales: 1250000
#    -> Bloque 26 OK. Filas totales: 1300000
#    -> Bloque 27 OK. Filas totales: 1350000
#    -> Bloque 28 OK. Filas totales: 1400000
#    -> Bloque 29 OK. Filas totales: 1450000
#    -> Bloque 30 OK. Filas totales: 1500000
#    -> Bloque 31 OK. Filas totales: 1550000
#    -> Bloque 32 OK. Filas totales: 1600000
#    -> Bloque 33 OK. Filas totales: 1650000
#    -> Bloque 34 OK. Filas totales: 1700000
#    -> Bloque 35 OK. Filas totales: 1750000
#    -> Bloque 36 OK. Filas totales: 1800000
#    -> Bloque 37 OK. Filas totales: 1850000
#    -> Bloque 38 OK. Filas totales: 1900000
#    -> Bloque 39 OK. Filas totales: 1950000
#    -> Bloque 40 OK. Filas totales: 2000000
#    -> Bloque 41 OK. Filas totales: 2050000
#    -> Bloque 42 OK. Filas totales: 2100000
#    -> Bloque 43 OK. Filas totales: 2150000
#    -> Bloque 44 OK. Filas totales: 2200000
#    -> Bloque 45 OK. Filas totales: 2250000
#    -> Bloque 46 OK. Filas totales: 2300000
#    -> Bloque 47 OK. Filas totales: 2350000
#    -> Bloque 48 OK. Filas totales: 2400000
#    -> Bloque 49 OK. Filas totales: 2450000
#    -> Bloque 50 OK. Filas totales: 2500000
#    -> Bloque 51 OK. Filas totales: 2550000
#    -> Bloque 52 OK. Filas totales: 2600000
#    -> Bloque 53 OK. Filas totales: 2650000
#    -> Bloque 54 OK. Filas totales: 2700000
#    -> Bloque 55 OK. Filas totales: 2750000
#    -> Bloque 56 OK. Filas totales: 2800000
#    -> Bloque 57 OK. Filas totales: 2850000
#    -> Bloque 58 OK. Filas totales: 2900000
#    -> Bloque 59 OK. Filas totales: 2950000
#    -> Bloque 60 OK. Filas totales: 3000000
#    -> Bloque 61 OK. Filas totales: 3050000
#    -> Bloque 62 OK. Filas totales: 3100000
#    -> Bloque 63 OK. Filas totales: 3150000
#    -> Bloque 64 OK. Filas totales: 3200000
#    -> Bloque 65 OK. Filas totales: 3250000
#    -> Bloque 66 OK. Filas totales: 3300000
#    -> Bloque 67 OK. Filas totales: 3350000
#    -> Bloque 68 OK. Filas totales: 3400000
#    -> Bloque 69 OK. Filas totales: 3450000
#    -> Bloque 70 OK. Filas totales: 3500000
#    -> Bloque 71 OK. Filas totales: 3550000
#    -> Bloque 72 OK. Filas totales: 3600000
#    -> Bloque 73 OK. Filas totales: 3650000
#    -> Bloque 74 OK. Filas totales: 3700000
#    -> Bloque 75 OK. Filas totales: 3750000
#    -> Bloque 76 OK. Filas totales: 3800000
#    -> Bloque 77 OK. Filas totales: 3850000
#    -> Bloque 78 OK. Filas totales: 3900000
#    -> Bloque 79 OK. Filas totales: 3950000
#    -> Bloque 80 OK. Filas totales: 4000000
#    -> Bloque 81 OK. Filas totales: 4050000
#    -> Bloque 82 OK. Filas totales: 4100000
#    -> Bloque 83 OK. Filas totales: 4150000
#    -> Bloque 84 OK. Filas totales: 4200000
#    -> Bloque 85 OK. Filas totales: 4250000
#    -> Bloque 86 OK. Filas totales: 4300000
#    -> Bloque 87 OK. Filas totales: 4350000
#    -> Bloque 88 OK. Filas totales: 4400000
#    -> Bloque 89 OK. Filas totales: 4450000
#    -> Bloque 90 OK. Filas totales: 4500000
#    -> Bloque 91 OK. Filas totales: 4550000
#    -> Bloque 92 OK. Filas totales: 4600000
#    -> Bloque 93 OK. Filas totales: 4650000
#    -> Bloque 94 OK. Filas totales: 4700000
#    -> Bloque 95 OK. Filas totales: 4750000
#    -> Bloque 96 OK. Filas totales: 4800000
#    -> Bloque 97 OK. Filas totales: 4850000
#    -> Bloque 98 OK. Filas totales: 4900000
#    -> Bloque 99 OK. Filas totales: 4950000
#    -> Bloque 100 OK. Filas totales: 5000000
#    -> Bloque 101 OK. Filas totales: 5050000
#    -> Bloque 102 OK. Filas totales: 5100000
#    -> Bloque 103 OK. Filas totales: 5150000
#    -> Bloque 104 OK. Filas totales: 5200000
#    -> Bloque 105 OK. Filas totales: 5250000
#    -> Bloque 106 OK. Filas totales: 5300000
#    -> Bloque 107 OK. Filas totales: 5350000
#    -> Bloque 108 OK. Filas totales: 5400000
#    -> Bloque 109 OK. Filas totales: 5450000
#    -> Bloque 110 OK. Filas totales: 5500000
#    -> Bloque 111 OK. Filas totales: 5550000
#    -> Bloque 112 OK. Filas totales: 5600000
#    -> Bloque 113 OK. Filas totales: 5650000
#    -> Bloque 114 OK. Filas totales: 5700000
#    -> Bloque 115 OK. Filas totales: 5750000
#    -> Bloque 116 OK. Filas totales: 5800000
#    -> Bloque 117 OK. Filas totales: 5850000
#    -> Bloque 118 OK. Filas totales: 5900000
#    -> Bloque 119 OK. Filas totales: 5950000
#    -> Bloque 120 OK. Filas totales: 6000000
#    -> Bloque 121 OK. Filas totales: 6050000
#    -> Bloque 122 OK. Filas totales: 6100000
#    -> Bloque 123 OK. Filas totales: 6150000
#    -> Bloque 124 OK. Filas totales: 6200000
#    -> Bloque 125 OK. Filas totales: 6250000
#    -> Bloque 126 OK. Filas totales: 6300000
#    -> Bloque 127 OK. Filas totales: 6350000
#    -> Bloque 128 OK. Filas totales: 6400000
#    -> Bloque 129 OK. Filas totales: 6450000
#    -> Bloque 130 OK. Filas totales: 6500000
#    -> Bloque 131 OK. Filas totales: 6550000
#    -> Bloque 132 OK. Filas totales: 6600000
#    -> Bloque 133 OK. Filas totales: 6650000
#    -> Bloque 134 OK. Filas totales: 6700000
#    -> Bloque 135 OK. Filas totales: 6750000
#    -> Bloque 136 OK. Filas totales: 6800000
#    -> Bloque 137 OK. Filas totales: 6850000
#    -> Bloque 138 OK. Filas totales: 6900000
#    -> Bloque 139 OK. Filas totales: 6950000
#    -> Bloque 140 OK. Filas totales: 7000000
#    -> Bloque 141 OK. Filas totales: 7050000
#    -> Bloque 142 OK. Filas totales: 7100000
#    -> Bloque 143 OK. Filas totales: 7150000
#    -> Bloque 144 OK. Filas totales: 7200000
#    -> Bloque 145 OK. Filas totales: 7250000
#    -> Bloque 146 OK. Filas totales: 7300000
#    -> Bloque 147 OK. Filas totales: 7350000
#    -> Bloque 148 OK. Filas totales: 7400000
#    -> Bloque 149 OK. Filas totales: 7450000
#    -> Bloque 150 OK. Filas totales: 7500000
#    -> Bloque 151 OK. Filas totales: 7550000
#    -> Bloque 152 OK. Filas totales: 7600000
#    -> Bloque 153 OK. Filas totales: 7650000
#    -> Bloque 154 OK. Filas totales: 7700000
#    -> Bloque 155 OK. Filas totales: 7750000
#    -> Bloque 156 OK. Filas totales: 7800000
#    -> Bloque 157 OK. Filas totales: 7850000
#    -> Bloque 158 OK. Filas totales: 7900000
#    -> Bloque 159 OK. Filas totales: 7950000
#    -> Bloque 160 OK. Filas totales: 8000000
#    -> Bloque 161 OK. Filas totales: 8050000
#    -> Bloque 162 OK. Filas totales: 8100000
#    -> Bloque 163 OK. Filas totales: 8150000
#    -> Bloque 164 OK. Filas totales: 8200000
#    -> Bloque 165 OK. Filas totales: 8250000
#    -> Bloque 166 OK. Filas totales: 8300000
#    -> Bloque 167 OK. Filas totales: 8350000
#    -> Bloque 168 OK. Filas totales: 8400000
#    -> Bloque 169 OK. Filas totales: 8450000
#    -> Bloque 170 OK. Filas totales: 8500000
#    -> Bloque 171 OK. Filas totales: 8550000
#    -> Bloque 172 OK. Filas totales: 8600000
#    -> Bloque 173 OK. Filas totales: 8650000
#    -> Bloque 174 OK. Filas totales: 8700000
#    -> Bloque 175 OK. Filas totales: 8750000
#    -> Bloque 176 OK. Filas totales: 8800000
#    -> Bloque 177 OK. Filas totales: 8850000
#    -> Bloque 178 OK. Filas totales: 8900000
#    -> Bloque 179 OK. Filas totales: 8950000
#    -> Bloque 180 OK. Filas totales: 9000000
#    -> Bloque 181 OK. Filas totales: 9050000
#    -> Bloque 182 OK. Filas totales: 9100000
#    -> Bloque 183 OK. Filas totales: 9150000
#    -> Bloque 184 OK. Filas totales: 9200000
#    -> Bloque 185 OK. Filas totales: 9250000
#    -> Bloque 186 OK. Filas totales: 9300000
#    -> Bloque 187 OK. Filas totales: 9350000
#    -> Bloque 188 OK. Filas totales: 9400000
#    -> Bloque 189 OK. Filas totales: 9450000
#    -> Bloque 190 OK. Filas totales: 9500000
#    -> Bloque 191 OK. Filas totales: 9550000
#    -> Bloque 192 OK. Filas totales: 9600000
#    -> Bloque 193 OK. Filas totales: 9650000
#    -> Bloque 194 OK. Filas totales: 9700000
#    -> Bloque 195 OK. Filas totales: 9750000
#    -> Bloque 196 OK. Filas totales: 9800000
#    -> Bloque 197 OK. Filas totales: 9850000
#    -> Bloque 198 OK. Filas totales: 9900000
#    -> Bloque 199 OK. Filas totales: 9950000
#    -> Bloque 200 OK. Filas totales: 10000000
#    -> Bloque 201 OK. Filas totales: 10050000
#    -> Bloque 202 OK. Filas totales: 10100000
#    -> Bloque 203 OK. Filas totales: 10150000
#    -> Bloque 204 OK. Filas totales: 10200000
#    -> Bloque 205 OK. Filas totales: 10250000
#    -> Bloque 206 OK. Filas totales: 10300000
#    -> Bloque 207 OK. Filas totales: 10350000
#    -> Bloque 208 OK. Filas totales: 10400000
#    -> Bloque 209 OK. Filas totales: 10450000
#    -> Bloque 210 OK. Filas totales: 10500000
#    -> Bloque 211 OK. Filas totales: 10550000
#    -> Bloque 212 OK. Filas totales: 10600000
#    -> Bloque 213 OK. Filas totales: 10650000
#    -> Bloque 214 OK. Filas totales: 10700000
#    -> Bloque 215 OK. Filas totales: 10750000
#    -> Bloque 216 OK. Filas totales: 10800000
#    -> Bloque 217 OK. Filas totales: 10850000
#    -> Bloque 218 OK. Filas totales: 10900000
#    -> Bloque 219 OK. Filas totales: 10950000
#    -> Bloque 220 OK. Filas totales: 11000000
#    -> Bloque 221 OK. Filas totales: 11050000
#    -> Bloque 222 OK. Filas totales: 11100000
#    -> Bloque 223 OK. Filas totales: 11150000
#    -> Bloque 224 OK. Filas totales: 11200000
#    -> Bloque 225 OK. Filas totales: 11250000
#    -> Bloque 226 OK. Filas totales: 11300000
#    -> Bloque 227 OK. Filas totales: 11350000
#    -> Bloque 228 OK. Filas totales: 11400000
#    -> Bloque 229 OK. Filas totales: 11450000
#    -> Bloque 230 OK. Filas totales: 11500000
#    -> Bloque 231 OK. Filas totales: 11550000
#    -> Bloque 232 OK. Filas totales: 11559010
# CARGA COMPLETADA: fact_inviales (11559010 filas)

# %%
import pandas as pd
from sqlalchemy import create_engine
import sys

# CONEXIÓN
db_connection_str = 'postgresql+psycopg2://postgres:as52@localhost:5432/Historico_Hechos_Movilidad'
engine = create_engine(db_connection_str)

def carga_definitiva(ruta_csv, nombre_tabla, mapeo_cols):
    print(f"\n[{nombre_tabla}] Iniciando carga...")
    chunksize = 50000 
    
    try:
        iterator = pd.read_csv(ruta_csv, chunksize=chunksize, encoding='latin-1')
        
        total_rows = 0
        for i, df in enumerate(iterator):
            # 1. Renombrar columnas
            df = df.rename(columns=mapeo_cols)
            
            # 2. Geometría PostGIS
            if 'longitud' in df.columns and 'latitud' in df.columns:
                mask = df['longitud'].notnull() & df['latitud'].notnull()
                df.loc[mask, 'geometria'] = df[mask].apply(
                    lambda x: f"SRID=4326;POINT({x['longitud']} {x['latitud']})", axis=1
                )
            
            # 3. Fechas
            if 'fk_tiempo' in df.columns:
                 df['fk_tiempo'] = pd.to_datetime(df['fk_tiempo'], errors='coerce')

            # 4. Filtrar columnas útiles
            cols_validas = [c for c in df.columns if c in mapeo_cols.values() or c == 'geometria']
            df = df[cols_validas]

            # 5. Insertar
            df.to_sql(nombre_tabla, engine, if_exists='append', index=False, method='multi', chunksize=5000)
            total_rows += len(df)
            print(f"   -> Bloque {i+1} OK. Filas totales: {total_rows}")

        print(f"CARGA COMPLETADA: {nombre_tabla} ({total_rows} filas)")

    except Exception as e:
        print(f"ERROR CRÍTICO: {e}")
        sys.exit(1)

# --- CONFIGURACIÓN ESPECÍFICA PARA ESTE SCRIPT ---
mapa_hechos = {
    'fecha_evento': 'fk_tiempo', 'hora_evento': 'hora_evento', 'tipo_evento': 'tipo_evento',
    'latitud': 'latitud', 'longitud': 'longitud', 'alcaldia': 'alcaldia', 'colonia': 'colonia',
    'SCORE_ATLAS': 'score_atlas', 'FLAG_HISTORICO': 'flag_historico', 'NIVEL_RIESGO_ESTATICO': 'nivel_riesgo_estatico'
}

# EJECUCIÓN
carga_definitiva(r"Data_Tratado\Hechos_Transito_Enriquecido.csv", "fact_hechos_transito", mapa_hechos)
# Out:
# [fact_hechos_transito] Iniciando carga...
#    -> Bloque 1 OK. Filas totales: 50000
#    -> Bloque 2 OK. Filas totales: 100000
#    -> Bloque 3 OK. Filas totales: 132065
# CARGA COMPLETADA: fact_hechos_transito (132065 filas)

# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
import urllib.parse
import sys

# --- CONFIGURACIÓN DE CONEXIÓN ---
USER = "postgres"
PASSWORD = "as52" 
HOST = "localhost"
PORT = "5432"
DB_NAME = "Historico_Hechos_Movilidad"

password_safe = urllib.parse.quote_plus(PASSWORD)
user_safe = urllib.parse.quote_plus(USER)
db_connection_str = f'postgresql+psycopg2://{user_safe}:{password_safe}@{HOST}:{PORT}/{DB_NAME}'
engine = create_engine(db_connection_str)

def simular_carga_pluviales(ruta_csv, nombre_tabla):
    print("Iniciando Simulación de Fenómeno de Lluvia (Interpolación Diaria)...")
    
    try:
        # 1. Carga del CSV mensual
        df = pd.read_csv(ruta_csv)
        
        # 2. Preprocesamiento
        # Asignamos el dato al día 15 de cada mes para centrar el fenómeno
        df['fecha_ref'] = pd.to_datetime(
            df['ANIO'].astype(str) + '-' + df['MES'].astype(str).str.zfill(2) + '-15'
        )
        
        # Seleccionamos columnas clave
        cols_base = ['CLAVE', 'NOMBRE', 'LON', 'LAT', 'PRECIPITACION', 'fecha_ref']
        df = df[cols_base].sort_values('fecha_ref')

        # 3. Motor de Interpolación (Simulación)
        dfs_simulados = []
        estaciones = df['CLAVE'].unique()
        
        total_estaciones = len(estaciones)
        print(f"   -> Procesando {total_estaciones} estaciones meteorológicas...")

        for idx, estacion in enumerate(estaciones):
            # Filtramos datos de una estación
            dfe = df[df['CLAVE'] == estacion].copy()
            
            # Eliminamos duplicados de fecha/estación si existen
            dfe = dfe.drop_duplicates(subset='fecha_ref')
            
            # Indexamos por fecha
            dfe = dfe.set_index('fecha_ref')
            
            # A. RESAMPLING: Creamos el esqueleto diario
            # B. INTERPOLACIÓN: 'time' conecta los puntos (día 15) linealmente
            #    Esto crea el efecto de transición suave entre meses (colas)
            dfe_diario = dfe.resample('D').interpolate(method='time')
            
            # Rellenamos metadatos estáticos (Nombre, Lat, Lon no cambian)
            dfe_diario['CLAVE'] = dfe_diario['CLAVE'].ffill().bfill()
            dfe_diario['NOMBRE'] = dfe_diario['NOMBRE'].ffill().bfill()
            dfe_diario['LON'] = dfe_diario['LON'].ffill().bfill()
            dfe_diario['LAT'] = dfe_diario['LAT'].ffill().bfill()
            
            # Reset index para recuperar la columna fecha
            dfe_diario = dfe_diario.reset_index().rename(columns={'fecha_ref': 'fecha'})
            
            dfs_simulados.append(dfe_diario)
            
            if (idx + 1) % 10 == 0:
                print(f"      ... Estación {idx + 1}/{total_estaciones} interpolada.")

        # 4. Consolidación
        df_final = pd.concat(dfs_simulados, ignore_index=True)
        
        # Limpieza final (eliminar días que pudieron quedar nulos en extremos muy lejanos)
        df_final = df_final.dropna(subset=['PRECIPITACION'])

        print(f"Simulación completada. Expandido a {len(df_final)} registros diarios.")

        # 5. Preparación para SQL
        # Renombrado
        df_final = df_final.rename(columns={
            'CLAVE': 'clave_estacion',
            'NOMBRE': 'nombre_estacion',
            'PRECIPITACION': 'precipitacion_simulada',
            'LON': 'longitud',
            'LAT': 'latitud',
            'fecha': 'fk_tiempo' # Usamos la fecha como FK
        })
        
        df_final['fecha'] = df_final['fk_tiempo'] # Duplicamos para tener campo fecha explicito

        # Geometría PostGIS
        df_final['geometria'] = df_final.apply(
            lambda x: f"SRID=4326;POINT({x['longitud']} {x['latitud']})", axis=1
        )

        # 6. Ingesta por bloques
        print(f"[{nombre_tabla}] Insertando en BD...")
        chunksize = 10000
        df_final.to_sql(
            nombre_tabla, 
            engine, 
            if_exists='append', 
            index=False, 
            method='multi', 
            chunksize=chunksize
        )
        print(f"CARGA DE PLUVIALES EXITOSA: {len(df_final)} filas.")

    except Exception as e:
        print(f"ERROR: {e}")
        import traceback
        traceback.print_exc()

# EJECUCIÓN
simular_carga_pluviales(r"Data_Tratado\Pluviales_DF.csv", "fact_pluviales")
# Out:
# Iniciando Simulación de Fenómeno de Lluvia (Interpolación Diaria)...
#    -> Procesando 265 estaciones meteorológicas...
#       ... Estación 10/265 interpolada.
#       ... Estación 20/265 interpolada.
#       ... Estación 30/265 interpolada.
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
#       ... Estación 40/265 interpolada.
#       ... Estación 50/265 interpolada.
#       ... Estación 60/265 interpolada.
#       ... Estación 70/265 interpolada.
#       ... Estación 80/265 interpolada.
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
#       ... Estación 90/265 interpolada.
#       ... Estación 100/265 interpolada.
#       ... Estación 110/265 interpolada.
#       ... Estación 120/265 interpolada.
#       ... Estación 130/265 interpolada.
#       ... Estación 140/265 interpolada.
#       ... Estación 150/265 interpolada.
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# ...
#       ... Estación 180/265 interpolada.
#       ... Estación 190/265 interpolada.
#       ... Estación 200/265 interpolada.
#       ... Estación 210/265 interpolada.
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
# C:\Users\artuk\AppData\Local\Temp\ipykernel_19384\1853868342.py:56: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dfe_diario = dfe.resample('D').interpolate(method='time')
#       ... Estación 220/265 interpolada.
#       ... Estación 230/265 interpolada.
#       ... Estación 240/265 interpolada.
#       ... Estación 250/265 interpolada.
#       ... Estación 260/265 interpolada.
# Simulación completada. Expandido a 433747 registros diarios.
# [fact_pluviales] Insertando en BD...
# CARGA DE PLUVIALES EXITOSA: 433747 filas.
