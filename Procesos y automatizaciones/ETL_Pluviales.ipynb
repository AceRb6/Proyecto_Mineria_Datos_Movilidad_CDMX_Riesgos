# %%
import pandas as pd
df=pd.read_csv(r"Pluviales\201301010000Lluv.csv", encoding="latin-1")

# %%
df.columns
# Out:
# Index(['LON', '   LAT', '   ESTADO', '     CVE_SIH', 'NOMBRE_ESTACION', 'ENE'], dtype='object')

# %%
import pandas as pd
import glob
import os

# Configuración de ruta
ruta_busqueda = r"Pluviales\*.csv"
archivos = glob.glob(ruta_busqueda)

# Verificación de existencia de archivos
if not archivos:
    raise FileNotFoundError("No se encontraron archivos en la ruta especificada.")

# Establecer referencia (Primer archivo)
archivo_base = archivos[0]
cols_referencia = list(pd.read_csv(archivo_base, encoding="latin-1", nrows=0).columns)

print(f"Archivo base: {os.path.basename(archivo_base)}")
print(f"Columnas referencia: {cols_referencia}")
print("-" * 40)

archivos_diferentes = {}

# Iteración y comparación
for archivo in archivos[1:]:
    try:
        # Leer solo encabezados
        cols_actual = list(pd.read_csv(archivo, encoding="latin-1", nrows=0).columns)
        
        # Comparar longitud y nombres exactos
        if cols_actual != cols_referencia:
            # Identificar diferencias de conjuntos
            set_ref = set(cols_referencia)
            set_act = set(cols_actual)
            faltantes = set_ref - set_act
            sobrantes = set_act - set_ref
            
            archivos_diferentes[os.path.basename(archivo)] = {
                "cols_actuales": cols_actual,
                "faltantes_en_archivo": list(faltantes),
                "sobrantes_en_archivo": list(sobrantes)
            }
            
    except Exception as e:
        archivos_diferentes[os.path.basename(archivo)] = f"Error de lectura: {str(e)}"

# Reporte de resultados
if not archivos_diferentes:
    print("ÉXITO: Todos los archivos comparten exactamente las mismas columnas.")
else:
    print(f"ADVERTENCIA: Se encontraron {len(archivos_diferentes)} archivos con inconsistencias:\n")
    for nombre, detalle in archivos_diferentes.items():
        print(f"Archivo: {nombre}")
        print(f"Detalle: {detalle}")
        print("-" * 20)
# Out:
# Archivo base: 201301010000Lluv.csv
# Columnas referencia: ['LON', '   LAT', '   ESTADO', '     CVE_SIH', 'NOMBRE_ESTACION', 'ENE']
# ----------------------------------------
# ADVERTENCIA: Se encontraron 143 archivos con inconsistencias:
#
# Archivo: 201302010000Lluv.csv
# Detalle: {'cols_actuales': ['  LON', '   LAT', '   ESTADO', '     CVE_SIH', 'NOMBRE_ESTACION', ' FEB'], 'faltantes_en_archivo': ['ENE', 'LON'], 'sobrantes_en_archivo': ['  LON', ' FEB']}
# --------------------
# Archivo: 201303010000Lluv.csv
# Detalle: {'cols_actuales': ['  LON', '   LAT', '   ESTADO', '     CVE_SIH', 'NOMBRE_ESTACION', ' MAR'], 'faltantes_en_archivo': ['ENE', 'LON'], 'sobrantes_en_archivo': ['  LON', ' MAR']}
# --------------------
# Archivo: 201304010000Lluv.csv
# Detalle: {'cols_actuales': ['  LON', '   LAT', '   ESTADO', '     CVE_SIH', 'NOMBRE_ESTACION', ' ABR'], 'faltantes_en_archivo': ['ENE', 'LON'], 'sobrantes_en_archivo': ['  LON', ' ABR']}
# --------------------
# Archivo: 201305010000Lluv.csv
# Detalle: {'cols_actuales': ['  LON', '   LAT', '   ESTADO', '     CVE_SIH', 'NOMBRE_ESTACION', ' MAY'], 'faltantes_en_archivo': ['ENE', 'LON'], 'sobrantes_en_archivo': ['  LON', ' MAY']}
# --------------------
# Archivo: 201306010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'ESTADO', 'CVE_SIH', 'NOMBRE_ESTACION', 'JUN'], 'faltantes_en_archivo': ['     CVE_SIH', 'ENE', '   LAT', '   ESTADO'], 'sobrantes_en_archivo': ['LAT', 'ESTADO', 'CVE_SIH', 'JUN']}
# --------------------
# Archivo: 201307010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'ESTADO', 'CVE_SIH', 'NOMBRE_ESTACION', 'JUL'], 'faltantes_en_archivo': ['     CVE_SIH', 'ENE', '   LAT', '   ESTADO'], 'sobrantes_en_archivo': ['LAT', 'ESTADO', 'JUL', 'CVE_SIH']}
# --------------------
# Archivo: 201308010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'ESTADO', 'CVE_SIH', 'NOMBRE_ESTACION', 'AGO'], 'faltantes_en_archivo': ['     CVE_SIH', 'ENE', '   LAT', '   ESTADO'], 'sobrantes_en_archivo': ['LAT', 'ESTADO', 'CVE_SIH', 'AGO']}
# --------------------
# Archivo: 201309010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'ESTADO', 'CVE_SIH', 'NOMBRE_ESTACION', 'SEP'], 'faltantes_en_archivo': ['     CVE_SIH', 'ENE', '   LAT', '   ESTADO'], 'sobrantes_en_archivo': ['LAT', 'ESTADO', 'CVE_SIH', 'SEP']}
# --------------------
# Archivo: 201310010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'ESTADO', 'CVE_SIH', 'NOMBRE_ESTACION', 'OCT'], 'faltantes_en_archivo': ['     CVE_SIH', 'ENE', '   LAT', '   ESTADO'], 'sobrantes_en_archivo': ['LAT', 'ESTADO', 'CVE_SIH', 'OCT']}
# --------------------
# Archivo: 201311010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'ESTADO', 'CVE_SIH', 'NOMBRE_ESTACION', 'NOV'], 'faltantes_en_archivo': ['     CVE_SIH', 'ENE', '   LAT', '   ESTADO'], 'sobrantes_en_archivo': ['LAT', 'ESTADO', 'CVE_SIH', 'NOV']}
# --------------------
# Archivo: 201312010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'ESTADO', 'CVE_SIH', 'NOMBRE_ESTACION', 'DIC'], 'faltantes_en_archivo': ['     CVE_SIH', 'ENE', '   LAT', '   ESTADO'], 'sobrantes_en_archivo': ['LAT', 'ESTADO', 'CVE_SIH', 'DIC']}
# --------------------
# Archivo: 201401010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'ESTADO', 'CVE_SIH', 'NOMBRE_ESTACION', 'ENE'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', '   ESTADO'], 'sobrantes_en_archivo': ['LAT', 'ESTADO', 'CVE_SIH']}
# --------------------
# Archivo: 201402010000Lluv.csv
# Detalle: {'cols_actuales': ['Lon', 'Lat', 'ESTADO', 'CVE_SIH', 'NOMBRE', 'FEB'], 'faltantes_en_archivo': ['     CVE_SIH', 'NOMBRE_ESTACION', '   ESTADO', 'LON', '   LAT', 'ENE'], 'sobrantes_en_archivo': ['NOMBRE', 'Lon', 'Lat', 'CVE_SIH', 'ESTADO', 'FEB']}
# --------------------
# Archivo: 201403010000Lluv.csv
# Detalle: {'cols_actuales': ['Lon', 'Lat', 'ESTADO', 'CVE_SIH', 'NOMBRE', 'MAR'], 'faltantes_en_archivo': ['     CVE_SIH', 'NOMBRE_ESTACION', '   ESTADO', 'LON', '   LAT', 'ENE'], 'sobrantes_en_archivo': ['NOMBRE', 'MAR', 'Lon', 'Lat', 'CVE_SIH', 'ESTADO']}
# --------------------
# Archivo: 201404010000Lluv.csv
# Detalle: {'cols_actuales': ['Lon', 'Lat', 'ESTADO', 'CVE_SIH', 'NOMBRE', 'ABR'], 'faltantes_en_archivo': ['     CVE_SIH', 'NOMBRE_ESTACION', '   ESTADO', 'LON', '   LAT', 'ENE'], 'sobrantes_en_archivo': ['NOMBRE', 'Lon', 'Lat', 'CVE_SIH', 'ESTADO', 'ABR']}
# --------------------
# Archivo: 201405010000Lluv.csv
# Detalle: {'cols_actuales': ['Lon', 'Lat', 'ESTADO', 'CVE_SIH', 'NOMBRE', 'MAY'], 'faltantes_en_archivo': ['     CVE_SIH', 'NOMBRE_ESTACION', '   ESTADO', 'LON', '   LAT', 'ENE'], 'sobrantes_en_archivo': ['NOMBRE', 'Lon', 'Lat', 'CVE_SIH', 'MAY', 'ESTADO']}
# --------------------
# Archivo: 201406010000Lluv.csv
# Detalle: {'cols_actuales': ['Lon', 'Lat', 'ESTADO', 'CVE_SIH', 'NOMBRE', 'JUN'], 'faltantes_en_archivo': ['     CVE_SIH', 'NOMBRE_ESTACION', '   ESTADO', 'LON', '   LAT', 'ENE'], 'sobrantes_en_archivo': ['NOMBRE', 'Lon', 'Lat', 'CVE_SIH', 'ESTADO', 'JUN']}
# --------------------
# Archivo: 201407010000Lluv.csv
# Detalle: {'cols_actuales': ['Lon', 'Lat', 'ESTADO', 'CVE_SIH', 'NOMBRE', 'JUL'], 'faltantes_en_archivo': ['     CVE_SIH', 'NOMBRE_ESTACION', '   ESTADO', 'LON', '   LAT', 'ENE'], 'sobrantes_en_archivo': ['NOMBRE', 'JUL', 'Lon', 'Lat', 'CVE_SIH', 'ESTADO']}
# --------------------
# Archivo: 201408010000Lluv.csv
# Detalle: {'cols_actuales': ['Lon', 'Lat', 'ESTADO', 'CVE_SIH', 'NOMBRE', 'AGO'], 'faltantes_en_archivo': ['     CVE_SIH', 'NOMBRE_ESTACION', '   ESTADO', 'LON', '   LAT', 'ENE'], 'sobrantes_en_archivo': ['NOMBRE', 'AGO', 'Lon', 'Lat', 'CVE_SIH', 'ESTADO']}
# --------------------
# Archivo: 201409010000Lluv.csv
# Detalle: {'cols_actuales': ['Lon', 'Lat', 'ESTADO', 'CVE_SIH', 'NOMBRE', 'SEP'], 'faltantes_en_archivo': ['     CVE_SIH', 'NOMBRE_ESTACION', '   ESTADO', 'LON', '   LAT', 'ENE'], 'sobrantes_en_archivo': ['NOMBRE', 'Lon', 'Lat', 'CVE_SIH', 'ESTADO', 'SEP']}
# --------------------
# Archivo: 201410010000Lluv.csv
# Detalle: {'cols_actuales': ['Lon', 'Lat', 'ESTADO', 'CVE_SIH', 'NOMBRE', 'OCT'], 'faltantes_en_archivo': ['     CVE_SIH', 'NOMBRE_ESTACION', '   ESTADO', 'LON', '   LAT', 'ENE'], 'sobrantes_en_archivo': ['NOMBRE', 'Lon', 'Lat', 'CVE_SIH', 'OCT', 'ESTADO']}
# --------------------
# Archivo: 201411010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'Lat', 'EDO', 'CLAVE', 'ESTACION', 'nov-14'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['Lat', 'nov-14', 'EDO', 'ESTACION', 'CLAVE']}
# --------------------
# Archivo: 201412010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'Lat', 'EDO', 'CLAVE', 'ESTACION', 'dic-14'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['Lat', 'EDO', 'dic-14', 'ESTACION', 'CLAVE']}
# --------------------
# Archivo: 201501010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'Lat', 'EDO', 'CLAVE', 'ESTACION', 'ene-15'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['ene-15', 'Lat', 'EDO', 'ESTACION', 'CLAVE']}
# --------------------
# Archivo: 201502010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'Lat', 'EDO', 'CLAVE', 'ESTACION', 'feb-15'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['feb-15', 'Lat', 'EDO', 'ESTACION', 'CLAVE']}
# --------------------
# Archivo: 201503010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'Lat', 'EDO', 'CLAVE', 'ESTACION', 'mar-15'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['mar-15', 'Lat', 'EDO', 'ESTACION', 'CLAVE']}
# --------------------
# Archivo: 201504010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'Lat', 'EDO', 'CLAVE', 'ESTACION', 'abr-15'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['abr-15', 'Lat', 'EDO', 'ESTACION', 'CLAVE']}
# --------------------
# Archivo: 201505010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'Lat', 'EDO', 'CLAVE', 'ESTACION', 'may-15'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['Lat', 'EDO', 'ESTACION', 'may-15', 'CLAVE']}
# --------------------
# Archivo: 201506010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'Lat', 'EDO', 'CLAVE', 'ESTACION', 'jun-15'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['jun-15', 'Lat', 'EDO', 'ESTACION', 'CLAVE']}
# --------------------
# Archivo: 201507010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'Lat', 'EDO', 'CLAVE', 'ESTACION', 'jul-15'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['Lat', 'jul-15', 'EDO', 'ESTACION', 'CLAVE']}
# --------------------
# Archivo: 201508010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'Lat', 'EDO', 'CLAVE', 'ESTACION', 'ago-15'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['Lat', 'ago-15', 'EDO', 'ESTACION', 'CLAVE']}
# --------------------
# Archivo: 201509010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'Lat', 'EDO', 'CLAVE', 'ESTACION', 'sep-15'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['Lat', 'sep-15', 'EDO', 'ESTACION', 'CLAVE']}
# --------------------
# Archivo: 201510010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'Lat', 'EDO', 'CLAVE', 'ESTACION', 'oct-15'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['Lat', 'oct-15', 'EDO', 'ESTACION', 'CLAVE']}
# --------------------
# Archivo: 201511010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'Lat', 'EDO', 'CLAVE', 'ESTACION', 'nov-15'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['Lat', 'EDO', 'nov-15', 'ESTACION', 'CLAVE']}
# --------------------
# Archivo: 201512010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'Lat', 'EDO', 'CLAVE', 'ESTACION', 'dic-15'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['Lat', 'dic-15', 'EDO', 'ESTACION', 'CLAVE']}
# --------------------
# Archivo: 201601010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'Lat', 'EDO', 'CLAVE', 'ESTACION', 'ene-16'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['ene-16', 'Lat', 'EDO', 'ESTACION', 'CLAVE']}
# --------------------
# Archivo: 201602010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'Lat', 'EDO', 'CLAVE', 'ESTACION', 'feb-16'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['feb-16', 'Lat', 'EDO', 'ESTACION', 'CLAVE']}
# --------------------
# Archivo: 201603010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'Lat', 'EDO', 'CLAVE', 'ESTACION', 'mar-16'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['mar-16', 'Lat', 'EDO', 'ESTACION', 'CLAVE']}
# --------------------
# Archivo: 201604010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'Lat', 'EDO', 'CLAVE', 'ESTACION', 'abr-16'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['Lat', 'EDO', 'ESTACION', 'CLAVE', 'abr-16']}
# --------------------
# Archivo: 201605010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'Lat', 'EDO', 'CLAVE', 'ESTACION', 'may-16'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['may-16', 'Lat', 'EDO', 'ESTACION', 'CLAVE']}
# --------------------
# Archivo: 201606010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'Lat', 'EDO', 'CLAVE', 'ESTACION', 'jun-16'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['jun-16', 'Lat', 'EDO', 'ESTACION', 'CLAVE']}
# --------------------
# Archivo: 201607010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'Lat', 'EDO', 'CLAVE', 'ESTACION', 'jul-16'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['jul-16', 'Lat', 'EDO', 'ESTACION', 'CLAVE']}
# --------------------
# Archivo: 201608010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'Lat', 'EDO', 'CLAVE', 'ESTACION', 'ago-16'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['Lat', 'ago-16', 'EDO', 'ESTACION', 'CLAVE']}
# --------------------
# Archivo: 201609010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'Lat', 'EDO', 'CLAVE', 'ESTACION', 'sep-16'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['Lat', 'EDO', 'ESTACION', 'sep-16', 'CLAVE']}
# --------------------
# Archivo: 201610010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'Lat', 'EDO', 'CLAVE', 'ESTACION', 'oct-16'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['oct-16', 'Lat', 'EDO', 'ESTACION', 'CLAVE']}
# --------------------
# Archivo: 201611010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'Lat', 'EDO', 'CLAVE', 'ESTACION', 'nov-16'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['Lat', 'EDO', 'ESTACION', 'CLAVE', 'nov-16']}
# --------------------
# Archivo: 201612010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'Lat', 'EDO', 'CLAVE', 'ESTACION', 'dic-16'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['Lat', 'dic-16', 'EDO', 'ESTACION', 'CLAVE']}
# --------------------
# Archivo: 201701010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'Lat', 'EDO', 'CLAVE', 'ESTACION', 'ene-17'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['ene-17', 'Lat', 'EDO', 'ESTACION', 'CLAVE']}
# --------------------
# Archivo: 201702010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'Lat', 'EDO', 'CLAVE', 'ESTACION', 'feb-17'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['Lat', 'EDO', 'feb-17', 'ESTACION', 'CLAVE']}
# --------------------
# Archivo: 201703010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'Lat', 'EDO', 'CLAVE', 'ESTACION', 'mar-17'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['Lat', 'mar-17', 'EDO', 'ESTACION', 'CLAVE']}
# --------------------
# Archivo: 201704010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'Lat', 'EDO', 'CLAVE', 'ESTACION', 'abr-17'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['Lat', 'abr-17', 'EDO', 'ESTACION', 'CLAVE']}
# --------------------
# Archivo: 201705010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'Lat', 'EDO', 'CLAVE', 'ESTACION', 'may-17'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['Lat', 'EDO', 'ESTACION', 'CLAVE', 'may-17']}
# --------------------
# Archivo: 201706010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'Lat', 'EDO', 'CLAVE', 'ESTACION', 'jun-17'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['jun-17', 'Lat', 'EDO', 'ESTACION', 'CLAVE']}
# --------------------
# Archivo: 201707010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'Lat', 'EDO', 'CLAVE', 'ESTACION', 'jul-17'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['jul-17', 'Lat', 'EDO', 'ESTACION', 'CLAVE']}
# --------------------
# Archivo: 201708010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'Lat', 'EDO', 'CLAVE', 'ESTACION', 'ago-17'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['ago-17', 'Lat', 'EDO', 'ESTACION', 'CLAVE']}
# --------------------
# Archivo: 201709010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'Lat', 'EDO', 'CLAVE', 'ESTACION', 'sep-17'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['Lat', 'sep-17', 'EDO', 'ESTACION', 'CLAVE']}
# --------------------
# Archivo: 201710010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'Lat', 'EDO', 'CLAVE', 'ESTACION', 'oct-17'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['Lat', 'EDO', 'ESTACION', 'oct-17', 'CLAVE']}
# --------------------
# Archivo: 201711010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'Lat', 'EDO', 'CLAVE', 'ESTACION', 'nov-17'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['Lat', 'EDO', 'ESTACION', 'nov-17', 'CLAVE']}
# --------------------
# Archivo: 201712010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'Lat', 'EDO', 'CLAVE', 'ESTACION', 'dic-17'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['dic-17', 'Lat', 'EDO', 'ESTACION', 'CLAVE']}
# --------------------
# Archivo: 201801010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'ESTADO', 'CLAVE_SIH', 'NOMBRE', 'ENE'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', '   ESTADO', 'NOMBRE_ESTACION'], 'sobrantes_en_archivo': ['LAT', 'NOMBRE', 'ESTADO', 'CLAVE_SIH']}
# --------------------
# Archivo: 201802010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'ESTADO', 'CLAVE_SIH', 'NOMBRE', 'FEB'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['LAT', 'NOMBRE', 'ESTADO', 'CLAVE_SIH', 'FEB']}
# --------------------
# Archivo: 201803010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'EDO', 'CLAVE_SIH', 'NOMBRE', 'MAR'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['LAT', 'NOMBRE', 'MAR', 'EDO', 'CLAVE_SIH']}
# --------------------
# Archivo: 201804010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'EDO', 'CLAVE_SIH', 'NOMBRE', 'ABR'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['LAT', 'NOMBRE', 'ABR', 'EDO', 'CLAVE_SIH']}
# --------------------
# Archivo: 201805010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'EDO', 'CLAVE_SIH', 'NOMBRE', 'MAY'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['LAT', 'NOMBRE', 'MAY', 'EDO', 'CLAVE_SIH']}
# --------------------
# Archivo: 201806010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'EDO', 'CLAVE_SIH', 'NOMBRE', 'JUN'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['LAT', 'NOMBRE', 'EDO', 'CLAVE_SIH', 'JUN']}
# --------------------
# Archivo: 201807010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'EDO', 'CLAVE_SIH', 'NOMBRE', 'JUL', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['LAT', 'NOMBRE', 'JUL', 'Unnamed: 10', 'Unnamed: 8', 'EDO', 'Unnamed: 9', 'Unnamed: 7', 'Unnamed: 6', 'CLAVE_SIH']}
# --------------------
# Archivo: 201808010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'EDO', 'CLAVE_SIH', 'NOMBRE', 'AGO'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['LAT', 'NOMBRE', 'AGO', 'EDO', 'CLAVE_SIH']}
# --------------------
# Archivo: 201809010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'EDO', 'CLAVE_SIH', 'NOMBRE', 'SEP'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['LAT', 'NOMBRE', 'EDO', 'SEP', 'CLAVE_SIH']}
# --------------------
# Archivo: 201810010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'EDO', 'CLAVE_SIH', 'NOMBRE', 'OCT'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['LAT', 'NOMBRE', 'OCT', 'EDO', 'CLAVE_SIH']}
# --------------------
# Archivo: 201811010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'EDO', 'CLAVE_SIH', 'NOMBRE', 'NOV'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['LAT', 'NOMBRE', 'NOV', 'EDO', 'CLAVE_SIH']}
# --------------------
# Archivo: 201812010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'EDO', 'CLAVE_SIH', 'NOMBRE', 'DIC'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['LAT', 'NOMBRE', 'DIC', 'EDO', 'CLAVE_SIH']}
# --------------------
# Archivo: 201901010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'EDO', 'CLAVE_SIH', 'NOMBRE', 'ENE'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', '   ESTADO', 'NOMBRE_ESTACION'], 'sobrantes_en_archivo': ['LAT', 'NOMBRE', 'EDO', 'CLAVE_SIH']}
# --------------------
# Archivo: 201902010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'EDO', 'CLAVE_SIH', 'NOMBRE', 'FEB'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['LAT', 'NOMBRE', 'EDO', 'CLAVE_SIH', 'FEB']}
# --------------------
# Archivo: 201903010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'EDO', 'CLAVE_SIH', 'NOMBRE', 'MAR'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['LAT', 'NOMBRE', 'MAR', 'EDO', 'CLAVE_SIH']}
# --------------------
# Archivo: 201904010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'EDO', 'CLAVE_SIH', 'NOMBRE', 'ABR'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['LAT', 'NOMBRE', 'ABR', 'EDO', 'CLAVE_SIH']}
# --------------------
# Archivo: 201905010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'EDO', 'CLAVE_SIH', 'NOMBRE', 'MAY'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['LAT', 'NOMBRE', 'MAY', 'EDO', 'CLAVE_SIH']}
# --------------------
# Archivo: 201906010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'EDO', 'CLAVE_SIH', 'NOMBRE', 'JUN'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['LAT', 'NOMBRE', 'EDO', 'CLAVE_SIH', 'JUN']}
# --------------------
# Archivo: 201907010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'EDO', 'CLAVE', 'ESTACION', 'JUL'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['LAT', 'JUL', 'EDO', 'ESTACION', 'CLAVE']}
# --------------------
# Archivo: 201908010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'EDO', 'CLAVE', 'ESTACION', 'AGO'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['LAT', 'AGO', 'EDO', 'ESTACION', 'CLAVE']}
# --------------------
# Archivo: 201909010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'EDO', 'CLAVE', 'ESTACION', 'SEP'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['LAT', 'EDO', 'SEP', 'ESTACION', 'CLAVE']}
# --------------------
# Archivo: 201910010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'EDO', 'CLAVE', 'ESTACION', 'oct-19'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['LAT', 'CLAVE', 'EDO', 'ESTACION', 'oct-19']}
# --------------------
# Archivo: 201911010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'EDO', 'CLAVE', 'ESTACION', 'nov-19'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['LAT', 'nov-19', 'EDO', 'ESTACION', 'CLAVE']}
# --------------------
# Archivo: 201912010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'EDO', 'CLAVE', 'ESTACION', 'dic-19'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['LAT', 'EDO', 'dic-19', 'ESTACION', 'CLAVE']}
# --------------------
# Archivo: 202001010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'EDO', 'CLAVE', 'ESTACION', 'ene-20'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['LAT', 'EDO', 'ene-20', 'ESTACION', 'CLAVE']}
# --------------------
# Archivo: 202002010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'EDO', 'CLAVE', 'ESTACION', 'feb-20'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['LAT', 'feb-20', 'EDO', 'ESTACION', 'CLAVE']}
# --------------------
# Archivo: 202003010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'EDO', 'CLAVE', 'ESTACION', 'mar-20'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['LAT', 'mar-20', 'EDO', 'ESTACION', 'CLAVE']}
# --------------------
# Archivo: 202004010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'EDO', 'CLAVE', 'ESTACION', 'abr-20'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['LAT', 'EDO', 'abr-20', 'ESTACION', 'CLAVE']}
# --------------------
# Archivo: 202005010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'EDO', 'CLAVE', 'ESTACION', 'may-20'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['LAT', 'EDO', 'ESTACION', 'CLAVE', 'may-20']}
# --------------------
# Archivo: 202006010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'EDO', 'CLAVE', 'ESTACION', 'jun-20'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['LAT', 'jun-20', 'EDO', 'ESTACION', 'CLAVE']}
# --------------------
# Archivo: 202007010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'EDO', 'CLAVE', 'ESTACION', 'jul-20'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['LAT', 'jul-20', 'EDO', 'ESTACION', 'CLAVE']}
# --------------------
# Archivo: 202008010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'EDO', 'CLAVE', 'ESTACION', 'ago-20'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['LAT', 'ago-20', 'EDO', 'ESTACION', 'CLAVE']}
# --------------------
# Archivo: 202009010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'EDO', 'CLAVE', 'ESTACION', 'sep-20'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['LAT', 'EDO', 'ESTACION', 'sep-20', 'CLAVE']}
# --------------------
# Archivo: 202010010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'EDO', 'CLAVE', 'ESTACION', 'oct-20', 'Unnamed: 6', 'Unnamed: 7'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['LAT', 'oct-20', 'EDO', 'Unnamed: 7', 'Unnamed: 6', 'ESTACION', 'CLAVE']}
# --------------------
# Archivo: 202011010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'EDO', 'CLAVE', 'ESTACION', 'nov-20'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['LAT', 'EDO', 'nov-20', 'ESTACION', 'CLAVE']}
# --------------------
# Archivo: 202012010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'EDO', 'CLAVE', 'ESTACION', 'dic-20'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['LAT', 'dic-20', 'EDO', 'ESTACION', 'CLAVE']}
# --------------------
# Archivo: 202101010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'EDO', 'CLAVE', 'ESTACION', 'ene-21'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['LAT', 'ene-21', 'EDO', 'ESTACION', 'CLAVE']}
# --------------------
# Archivo: 202102010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'EDO', 'CLAVE', 'ESTACION', 'feb-21'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['LAT', 'CLAVE', 'EDO', 'ESTACION', 'feb-21']}
# --------------------
# Archivo: 202103010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'EDO', 'CLAVE', 'ESTACION', 'mar-21'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['LAT', 'EDO', 'mar-21', 'ESTACION', 'CLAVE']}
# --------------------
# Archivo: 202104010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'EDO', 'CLAVE', 'ESTACION', 'abr-21'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['LAT', 'EDO', 'ESTACION', 'abr-21', 'CLAVE']}
# --------------------
# Archivo: 202105010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'EDO', 'CLAVE', 'ESTACION', 'may-21'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['LAT', 'may-21', 'EDO', 'ESTACION', 'CLAVE']}
# --------------------
# Archivo: 202106010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'EDO', 'CLAVE', 'ESTACION', 'jun-21'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['LAT', 'EDO', 'ESTACION', 'jun-21', 'CLAVE']}
# --------------------
# Archivo: 202107010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'EDO', 'CLAVE', 'ESTACION', 'jul-21'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['LAT', 'jul-21', 'EDO', 'ESTACION', 'CLAVE']}
# --------------------
# Archivo: 202108010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'EDO', 'CLAVE', 'ESTACION', 'ago-21'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['LAT', 'ago-21', 'EDO', 'ESTACION', 'CLAVE']}
# --------------------
# Archivo: 202109010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'EDO', 'CLAVE', 'ESTACION', '09-sep'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['LAT', 'EDO', 'ESTACION', 'CLAVE', '09-sep']}
# --------------------
# Archivo: 202110010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'EDO', 'CLAVE', 'ESTACION', 'oct-21'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['LAT', 'oct-21', 'EDO', 'ESTACION', 'CLAVE']}
# --------------------
# Archivo: 202111010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'EDO', 'CLAVE', 'ESTACION', 'nov-21'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['LAT', 'CLAVE', 'EDO', 'ESTACION', 'nov-21']}
# --------------------
# Archivo: 202112010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'EDO', 'CLAVE', 'ESTACION', 'dic-21'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['LAT', 'dic-21', 'EDO', 'ESTACION', 'CLAVE']}
# --------------------
# Archivo: 202201010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'EDO', 'CLAVE', 'ESTACION', 'ene-22'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['LAT', 'EDO', 'ESTACION', 'ene-22', 'CLAVE']}
# --------------------
# Archivo: 202202010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'EDO', 'CLAVE', 'ESTACION', 'feb-22'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['LAT', 'feb-22', 'EDO', 'ESTACION', 'CLAVE']}
# --------------------
# Archivo: 202203010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'EDO', 'CLAVE', 'ESTACION', 'mar-22'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['LAT', 'EDO', 'ESTACION', 'mar-22', 'CLAVE']}
# --------------------
# Archivo: 202204010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'EDO', 'CLAVE', 'ESTACION', 'abr-22'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['LAT', 'abr-22', 'EDO', 'ESTACION', 'CLAVE']}
# --------------------
# Archivo: 202205010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'EDO', 'CLAVE', 'ESTACION', 'may-22'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['LAT', 'may-22', 'EDO', 'ESTACION', 'CLAVE']}
# --------------------
# Archivo: 202206010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'EDO', 'CLAVE', 'ESTACION', 'jun-22'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['LAT', 'jun-22', 'EDO', 'ESTACION', 'CLAVE']}
# --------------------
# Archivo: 202207010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'EDO', 'CLAVE', 'ESTACION', 'jul-22', 'Unnamed: 6', 'Unnamed: 7'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['LAT', 'jul-22', 'EDO', 'Unnamed: 7', 'Unnamed: 6', 'ESTACION', 'CLAVE']}
# --------------------
# Archivo: 202208010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'EDO', 'CLAVE', 'ESTACION', 'ago-22'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['LAT', 'CLAVE', 'EDO', 'ESTACION', 'ago-22']}
# --------------------
# Archivo: 202209010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'EDO', 'CLAVE', 'ESTACION', 'sep-22'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['LAT', 'EDO', 'ESTACION', 'CLAVE', 'sep-22']}
# --------------------
# Archivo: 202210010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'EDO', 'CLAVE', 'ESTACION', 'oct-22'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['LAT', 'oct-22', 'EDO', 'ESTACION', 'CLAVE']}
# --------------------
# Archivo: 202211010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'EDO', 'CLAVE', 'ESTACION', 'nov-22'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['LAT', 'nov-22', 'EDO', 'ESTACION', 'CLAVE']}
# --------------------
# Archivo: 202212010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'EDO', 'CLAVE', 'ESTACION', 'dic-22'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['LAT', 'dic-22', 'EDO', 'ESTACION', 'CLAVE']}
# --------------------
# Archivo: 202301010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'EDO', 'CLAVE', 'ESTACION', 'ene-23'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['LAT', 'ene-23', 'EDO', 'ESTACION', 'CLAVE']}
# --------------------
# Archivo: 202302010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'EDO', 'CLAVE', 'ESTACION', 'feb-23'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['LAT', 'feb-23', 'EDO', 'ESTACION', 'CLAVE']}
# --------------------
# Archivo: 202303010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'EDO', 'CLAVE', 'ESTACION', 'mar-23'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['LAT', 'EDO', 'ESTACION', 'CLAVE', 'mar-23']}
# --------------------
# Archivo: 202304010000Lluv.csv
# Detalle: {'cols_actuales': ['EST', 'XLO', 'YLA', 'NAME', 'ESTADO', 'abr-23'], 'faltantes_en_archivo': ['     CVE_SIH', 'NOMBRE_ESTACION', '   ESTADO', 'LON', '   LAT', 'ENE'], 'sobrantes_en_archivo': ['abr-23', 'YLA', 'EST', 'ESTADO', 'NAME', 'XLO']}
# --------------------
# Archivo: 202305010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'EDO', 'CLAVE', 'ESTACION', 'may-23'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['LAT', 'EDO', 'may-23', 'ESTACION', 'CLAVE']}
# --------------------
# Archivo: 202306010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'EDO', 'CLAVE', 'ESTACION', 'jun-23'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['LAT', 'EDO', 'ESTACION', 'jun-23', 'CLAVE']}
# --------------------
# Archivo: 202307010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'EDO', 'CLAVE', 'ESTACION', 'jul-23'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['LAT', 'jul-23', 'EDO', 'ESTACION', 'CLAVE']}
# --------------------
# Archivo: 202308010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'EDO', 'CLAVE', 'ESTACION', 'ago-23'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['LAT', 'ago-23', 'EDO', 'ESTACION', 'CLAVE']}
# --------------------
# Archivo: 202309010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'EDO', 'CLAVE', 'ESTACION', 'sep-23'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['LAT', 'ESTACION', 'EDO', 'sep-23', 'CLAVE']}
# --------------------
# Archivo: 202310010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'EDO', 'CLAVE', 'ESTACION', 'oct-23'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['LAT', 'EDO', 'oct-23', 'ESTACION', 'CLAVE']}
# --------------------
# Archivo: 202311010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'EDO', 'CLAVE', 'ESTACION', 'nov-23'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['LAT', 'EDO', 'nov-23', 'ESTACION', 'CLAVE']}
# --------------------
# Archivo: 202312010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'EDO', 'CLAVE', 'ESTACION', 'dic-23'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['LAT', 'EDO', 'dic-23', 'ESTACION', 'CLAVE']}
# --------------------
# Archivo: 202401010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'EDO', 'CLAVE', 'ESTACION', 'ene-24'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['LAT', 'ene-24', 'EDO', 'ESTACION', 'CLAVE']}
# --------------------
# Archivo: 202402010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'EDO', 'CLAVE', 'ESTACION', 'feb-24'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['LAT', 'EDO', 'ESTACION', 'CLAVE', 'feb-24']}
# --------------------
# Archivo: 202403010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'EDO', 'CLAVE', 'ESTACION', 'mar-23'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['LAT', 'EDO', 'ESTACION', 'CLAVE', 'mar-23']}
# --------------------
# Archivo: 202404010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'EDO', 'CLAVE', 'ESTACION', 'abr-24'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['LAT', 'EDO', 'ESTACION', 'CLAVE', 'abr-24']}
# --------------------
# Archivo: 202405010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'EDO', 'CLAVE', 'ESTACION', 'may-24'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['LAT', 'may-24', 'EDO', 'ESTACION', 'CLAVE']}
# --------------------
# Archivo: 202406010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'EDO', 'CLAVE', 'ESTACION', 'jun-24'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['LAT', 'EDO', 'jun-24', 'ESTACION', 'CLAVE']}
# --------------------
# Archivo: 202407010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'EDO', 'CLAVE', 'ESTACION', 'jul-24'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['LAT', 'EDO', 'ESTACION', 'jul-24', 'CLAVE']}
# --------------------
# Archivo: 202408010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'EDO', 'CLAVE', 'ESTACION', 'sep-24'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['LAT', 'sep-24', 'EDO', 'ESTACION', 'CLAVE']}
# --------------------
# Archivo: 202409010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'EDO', 'CLAVE', 'ESTACION', 'sep-24'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['LAT', 'sep-24', 'EDO', 'ESTACION', 'CLAVE']}
# --------------------
# Archivo: 202410010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'EDO', 'CLAVE', 'ESTACION', 'oct-24'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['LAT', 'EDO', 'ESTACION', 'CLAVE', 'oct-24']}
# --------------------
# Archivo: 202411010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'EDO', 'CLAVE', 'ESTACION', 'nov-24'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['LAT', 'nov-24', 'EDO', 'ESTACION', 'CLAVE']}
# --------------------
# Archivo: 202412010000Lluv.csv
# Detalle: {'cols_actuales': ['LON', 'LAT', 'EDO', 'CLAVE', 'ESTACION', 'dic-24'], 'faltantes_en_archivo': ['     CVE_SIH', '   LAT', 'NOMBRE_ESTACION', '   ESTADO', 'ENE'], 'sobrantes_en_archivo': ['LAT', 'dic-24', 'EDO', 'ESTACION', 'CLAVE']}
# --------------------

# %%
import pandas as pd
import glob
import os

# Configuración
ruta_archivos = r"Pluviales\*.csv"
archivos = glob.glob(ruta_archivos)

dfs = []

# Mapeo de columnas estándar (Normalizado a mayúsculas y sin espacios)
# Estructura: {Nombre_Final: [Lista de posibles nombres originales]}
mapa_columnas = {
    'LON': ['LON', 'XLO', 'LONGITUD'],
    'LAT': ['LAT', 'YLA', 'LATITUD'],
    'ESTADO': ['ESTADO', 'EDO'],
    'CLAVE': ['CLAVE', 'CVE_SIH', 'CLAVE_SIH', 'CVE', 'EST'], # 'EST' para caso 202304
    'NOMBRE': ['NOMBRE', 'NOMBRE_ESTACION', 'ESTACION', 'NAME']
}

print(f"Procesando {len(archivos)} archivos...")

for archivo in archivos:
    try:
        # 1. Extracción de metadatos del nombre del archivo
        nombre_archivo = os.path.basename(archivo)
        anio = nombre_archivo[:4]
        mes = nombre_archivo[4:6]
        
        # 2. Lectura del archivo
        # Se asume encoding latin-1 por los acentos en México
        df = pd.read_csv(archivo, encoding="latin-1")
        
        # 3. Limpieza de encabezados
        # Eliminar espacios, convertir a mayúsculas
        df.columns = df.columns.str.strip().str.upper()
        
        # Eliminar columnas 'Unnamed' (basura generada por comas extra)
        cols_validas = [c for c in df.columns if not c.startswith('UNNAMED')]
        df = df[cols_validas]
        
        # 4. Normalización de columnas
        cols_finales = {}
        col_precipitacion = None
        
        columnas_identificadas = []
        
        for col in df.columns:
            identificada = False
            for estandar, variantes in mapa_columnas.items():
                if col in variantes:
                    cols_finales[col] = estandar
                    columnas_identificadas.append(estandar)
                    identificada = True
                    break
            
            # Si no es una columna estándar de ubicación/id, asumimos que es la precipitación
            if not identificada:
                if col_precipitacion is None:
                    col_precipitacion = col
                    cols_finales[col] = 'PRECIPITACION'
                else:
                    # Si ya tenemos precipitación y aparece otra columna desconocida, es una anomalía
                    # Pero en este dataset, asumiremos que la primera desconocida es la lluvia
                    pass

        # Renombrar
        df = df.rename(columns=cols_finales)
        
        # 5. Estandarización final
        # Asegurar que existan todas las columnas base, si falta alguna se rellena con NaN
        columnas_base = ['CLAVE', 'NOMBRE', 'ESTADO', 'LON', 'LAT', 'PRECIPITACION']
        for col in columnas_base:
            if col not in df.columns:
                df[col] = None 
                
        # Agregar columnas temporales
        df['ANIO'] = anio
        df['MES'] = mes
        
        # Seleccionar y ordenar
        df_final = df[columnas_base + ['ANIO', 'MES']]
        
        dfs.append(df_final)

    except Exception as e:
        print(f"Error procesando {nombre_archivo}: {e}")

# Consolidación
if dfs:
    df_consolidado = pd.concat(dfs, ignore_index=True)
    
    # Conversión de tipos para optimizar y limpiar
    # Convertir precipitación a numérico, forzando errores a NaN (ej. trazas o textos)
    df_consolidado['PRECIPITACION'] = pd.to_numeric(df_consolidado['PRECIPITACION'], errors='coerce')
    
    print("-" * 30)
    print(f"Consolidación completada.")
    print(f"Total registros: {len(df_consolidado)}")
    display(df_consolidado.head())
else:
    print("No se generaron datos para consolidar.")
# Out:
# Procesando 144 archivos...
# ------------------------------
# Consolidación completada.
# Total registros: 160080
#    CLAVE                 NOMBRE ESTADO     LON    LAT  PRECIPITACION  ANIO MES
# 0  AGSAG         AGUASCALIENTES    AGS -102.31  21.90           58.5  2013  01
# 1  ANVAG  CINCUENTA ANIVERSARIO    AGS -102.47  22.19            0.0  2013  01
# 2  BRTAG            SAN BARTOLO    AGS -102.18  21.74           17.0  2013  01
# 3  CDRAG            LA CODORNIZ    AGS -102.67  22.00           45.0  2013  01
# 4  CLVAG             CALVILLITO    AGS -102.19  21.83           60.5  2013  01

# %%
# Asumiendo que 'df_consolidado' está en memoria del paso anterior.
# Si no, cargar: df_consolidado = pd.read_csv("Consolidado_Pluviales.csv")

# 1. Normalización de la columna ESTADO
# Se convierte a mayúsculas y se eliminan espacios al inicio/final
df_consolidado['ESTADO'] = df_consolidado['ESTADO'].astype(str).str.strip().str.upper()

# 2. Definición de criterios de búsqueda
# Incluye nomenclatura antigua (DF) y actual (CDMX)
variantes_df = 'DF'

# 3. Filtrado
df_df = df_consolidado[df_consolidado['ESTADO'] == variantes_df].copy()

# 4. Verificación y Exportación
print(f"Registros encontrados para DF/CDMX: {len(df_df)}")
print("Variantes encontradas en la columna ESTADO:", df_df['ESTADO'].unique())

if not df_df.empty:
    display(df_df.head())
else:
    print("No se encontraron registros que coincidan con DF/CDMX.")
# Out:
# Registros encontrados para DF/CDMX: 9672
# Variantes encontradas en la columna ESTADO: ['DF']
#      CLAVE                                             NOMBRE ESTADO    LON  \
# 189  AJSDF                                             AJUSCO     DF -99.21
# 190  CBIDF  ESCUELA NACIONAL DE CIENCIAS BIOLOGICAS, IPN (...     DF -99.17
# 191  CCUDF                               CENTRO UNIVERSITARIO     DF -99.18
# 192  CDMDF                                  CARCEL DE MUJERES     DF -99.00
# 193  CDVDF                                   CIUDAD DEPORTIVA     DF -99.11
#
#        LAT  PRECIPITACION  ANIO MES
# 189  19.22           20.5  2013  01
# 190  19.45            1.3  2013  01
# 191  19.35            0.2  2013  01
# 192  19.36            0.0  2013  01
# 193  19.41            0.8  2013  01

# %%
import os

# Configuración de ruta
directorio_salida = "Data_Tratado"
nombre_archivo = "Pluviales_DF.csv"

# Crear directorio (exist_ok=True evita error si ya existe)
os.makedirs(directorio_salida, exist_ok=True)

# Construcción de ruta absoluta/relativa
ruta_completa = os.path.join(directorio_salida, nombre_archivo)

# Exportar
try:
    df_df.to_csv(ruta_completa, index=False, encoding='utf-8-sig')
    print(f"EXPORTACIÓN EXITOSA: {ruta_completa}")
except NameError:
    print("ERROR: El DataFrame 'df_df' no está definido en memoria. Ejecute el filtrado previo.")
except Exception as e:
    print(f"ERROR DE ESCRITURA: {str(e)}")
# Out:
# EXPORTACIÓN EXITOSA: Data_Tratado\Pluviales_DF.csv

# %%
df_df.to_csv(ruta_completa, index=False, encoding='utf-8-sig')

# %%
df_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9672 entries, 189 to 159307
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CLAVE          9672 non-null   object
#  1   NOMBRE         9672 non-null   object
#  2   ESTADO         9672 non-null   object
#  3   LON            9672 non-null   float64
#  4   LAT            9672 non-null   float64
#  5   PRECIPITACION  9672 non-null   float64
#  6   ANIO           9672 non-null   object
#  7   MES            9672 non-null   object
# dtypes: float64(3), object(5)
# memory usage: 680.1+ KB

# %%
df_df.describe()
# Out:
#                LON          LAT  PRECIPITACION
# count  9672.000000  9672.000000    9672.000000
# mean    -99.147791    19.361229      57.033590
# std       0.082678     0.096949      71.495107
# min     -99.440556    18.861389       0.000000
# 25%     -99.205000    19.300000       2.800000
# 50%     -99.142500    19.360000      24.600000
# 75%     -99.090000    19.435556      92.932500
# max     -98.960000    19.633333     629.250000
